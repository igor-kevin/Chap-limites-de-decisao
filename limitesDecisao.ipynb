# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model
from mlxtend.plotting import plot_decision_regions
import pandas as pd

# %% [markdown]
# ## Parte 1

# %%
modelo = linear_model.LinearRegression()
carros = pd.read_csv('carros.csv', sep=';')
carros
# Out:
#     Consumo  Cilindros  Cilindradas  ...  Marchas  Carburadors   HP
# 0        21          6          160  ...        4            4  110
# 1        21          6          160  ...        4            4  110
# 2       228          4          108  ...        4            1   93
# 3       214          6          258  ...        3            1  110
# 4       187          8          360  ...        3            2  175
# 5       181          6          225  ...        3            1  105
# 6       143          8          360  ...        3            4  245
# 7       244          4         1467  ...        4            2   62
# 8       228          4         1408  ...        4            2   95
# 9       192          6         1676  ...        4            4  123
# 10      178          6         1676  ...        4            4  123
# 11      164          8         2758  ...        3            3  180
# 12      173          8         2758  ...        3            3  180
# ...

# %%
carros_np = carros.to_numpy()

# %%
# prever o número de carburadores
y = carros_np[:,9]
# Consumo e cilindros
X = carros_np[:,0:2]
y
# Out:
# array([4, 4, 1, 1, 2, 1, 4, 2, 2, 4, 4, 3, 3, 3, 4, 4, 4, 1, 2, 1, 1, 2,
#        2, 4, 2, 1, 2, 2, 4, 6, 8, 2])

# %%
X
# Out:
# array([[ 21,   6],
#        [ 21,   6],
#        [228,   4],
#        [214,   6],
#        [187,   8],
#        [181,   6],
#        [143,   8],
#        [244,   4],
#        [228,   4],
#        [192,   6],
#        [178,   6],
#        [164,   8],
#        [173,   8],
#        [152,   8],
#        [104,   8],
#        [104,   8],
#        [147,   8],
#        [324,   4],
#        [304,   4],
#        [339,   4],
#        [215,   4],
#        [155,   8],
#        [152,   8],
#        [133,   8],
#        [192,   8],
#        [273,   4],
#        [ 26,   4],
#        [304,   4],
#        [158,   8],
#        [197,   6],
#        [ 15,   8],
#        [214,   4]])

# %%
modelo.fit(X, y)
# Out:
# LinearRegression()

# %%
fig = plot_decision_regions(X=X, y=y, clf=modelo)
plt.legend(bbox_to_anchor=(1.04, 1), loc='upper left', ncol=2)
plt.title('limites de decisão')
plt.xlabel('Consumo')
plt.ylabel('Cilindros')
plt.show()
# Out:
# d:\Cientista_dados_2_extras\Chap limites de decisao\.venv\Lib\site-packages\mlxtend\plotting\decision_regions.py:346: UserWarning: You passed a edgecolor/edgecolors ('black') for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   ax.scatter(

# %% [markdown]
# ## Parte 2

# %%
from mlxtend.classifier import EnsembleVoteClassifier

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
modelo_arvore = RandomForestClassifier(random_state=0)
modelo_arvore.fit(X, y)
# Out:
# RandomForestClassifier(random_state=0)

# %%
fig = plot_decision_regions(X=X, y=y, clf=modelo_arvore)
plt.legend(bbox_to_anchor=(1.04, 1), loc='upper left', ncol=2)
plt.title('limites de decisão')
plt.xlabel('Consumo')
plt.ylabel('Cilindros')
plt.show()
# Out:
# d:\Cientista_dados_2_extras\Chap limites de decisao\.venv\Lib\site-packages\mlxtend\plotting\decision_regions.py:346: UserWarning: You passed a edgecolor/edgecolors ('black') for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   ax.scatter(
